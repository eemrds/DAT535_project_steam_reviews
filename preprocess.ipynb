# %% [markdown]
# # Data Cleaning

# %%
import findspark

from delta import *
from pyspark import SparkContext, SparkConf, RDD
import csv
from io import StringIO
from pyspark.sql import Row, SparkSession
from pyspark.sql.types import (
    StructType,
    StructField,
    StringType,
    IntegerType,
    DoubleType,
    BooleanType,
)
from delta import configure_spark_with_delta_pip


findspark.init()


CSV_FOLDER = "hdfs:///steam_reviews/csvs"
TMP_FOLDER = "hdfs:///steam_reviews/steam_reviews_temp"
TMP_TABLE = "hdfs:///steam_reviews/steam_reviews_collected"
DELTA_TABLE = "hdfs:///steam_reviews/steam_reviews_processed"

# AUTHOR_DELTA = "hdfs:///steam_reviews/steam_reviews_author"
# GAME_DELTA = "hdfs:///steam_reviews/steam_reviews_game"

# %%
conf = (
    SparkConf()
    .setAppName("steam_reviews_csvs")
    .set("spark.driver.memory", "6g")
    .set("spark.executor.memory", "6g")
)
sc = SparkContext(conf=conf)

# %% [markdown]
# # Preprocessing data
#
# Due to the feedback received during the presentation, we re-preprocessed the data and this time used spark
#
# The preprocessing takes the filename and the text/csv data from the rdd and updates to csv with game name and appid extracted from the filename.
# In addition newlines are removed and from the the rows.

# %%
header = "appid,game,index,recommendationid,language,review,timestamp_created,timestamp_updated,voted_up,votes_up,votes_funny,weighted_vote_score,comment_count,steam_purchase,received_for_free,written_during_early_access,author_steamid,author_num_games_owned,author_num_reviews,author_playtime_forever,author_playtime_last_two_weeks,author_playtime_at_review,author_last_played"

# %%
def preprocess_csv(data_init):
    try:
        file_name, data = data_init
        appid, game = tuple(file_name.split("/")[-1].split("_"))
        game = game.replace(".csv", "")

        file = list(csv.reader(StringIO(data)))

        header = ["appid", "game", "index"] + file[0][1:]

        output = StringIO()
        writer = csv.writer(output)

        # writer.writerow(header)
        for row in file[1:]:
            writer.writerow(
                [
                    str(c).replace("\r\n", " ").replace("\n", " ").replace(",", " - ")
                    for c in [appid, game] + row
                ]
            )

        data = output.getvalue()
        output.close()
        return data
    except Exception as e:
        print(data)
        print(e)
        return None

# %% [markdown]
# # Upload csvs to hadoop
#
# Due to the size of the data, there is not enough memory to use collect() or just saveAsTextFile().
# The map job has to be split up into partitions, saved and re-read once the job is complete.
# It is therefore saved to a temporary folder.
#
# * hdfs dfs -mkdir /steam_reviews
# * hdfs dfs -mkdir /steam_reviews/csvs
# * hdfs dfs -put steam_reviews_csvs/*.csv /steam_reviews/csvs

# %%
reviews = sc.wholeTextFiles(CSV_FOLDER)
processed_reviews = reviews.mapPartitions(
    lambda partition: (preprocess_csv(record) for record in partition)
).filter(lambda row: row if row and row != header else False)

processed_reviews.saveAsTextFile(TMP_FOLDER)

# %% [markdown]
# # Uploading to delta table
# Now that the data is preprocessed with the bear necessities to have all necessary field, the data can be written to a deltatable

# %%
builder = (
    SparkSession.builder.appName("Preprocess")
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config(
        "spark.sql.catalog.spark_catalog",
        "org.apache.spark.sql.delta.catalog.DeltaCatalog",
    )
    .config("spark.executor.memory", "4g")
    .config("spark.driver.memory", "4g")
    .config("spark.driver.maxResultSize", "2g")
)

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
schema = StructType(
    [
        StructField("appid", StringType()),
        StructField("game", StringType()),
        StructField("index", StringType()),
        StructField("recommendationid", StringType()),
        StructField("language", StringType()),
        StructField("review", StringType()),
        StructField("timestamp_created", IntegerType()),
        StructField("timestamp_updated", IntegerType()),
        StructField("voted_up", BooleanType()),
        StructField("votes_up", IntegerType()),
        StructField("votes_funny", IntegerType()),
        StructField("weighted_vote_score", DoubleType()),
        StructField("comment_count", IntegerType()),
        StructField("steam_purchase", BooleanType()),
        StructField("received_for_free", BooleanType()),
        StructField("written_during_early_access", BooleanType()),
        StructField("author_steamid", StringType()),
        StructField("author_num_games_owned", IntegerType()),
        StructField("author_num_reviews", IntegerType()),
        StructField("author_playtime_forever", IntegerType()),
        StructField("author_playtime_last_two_weeks", IntegerType()),
        StructField("author_playtime_at_review", IntegerType()),
        StructField("author_last_played", IntegerType()),
    ]
)

# %%
reviews = spark.read.csv(TMP_FOLDER, schema=schema)

# df = df.toDF(*header.split(","))
reviews.show()
# Out:
# +-------+--------------------+-----+----------------+--------+--------------------+-----------------+-----------------+--------+--------+-----------+-------------------+-------------+--------------+-----------------+---------------------------+-----------------+----------------------+------------------+-----------------------+------------------------------+-------------------------+------------------+
# |  appid|                game|index|recommendationid|language|              review|timestamp_created|timestamp_updated|voted_up|votes_up|votes_funny|weighted_vote_score|comment_count|steam_purchase|received_for_free|written_during_early_access|   author_steamid|author_num_games_owned|author_num_reviews|author_playtime_forever|author_playtime_last_two_weeks|author_playtime_at_review|author_last_played|
# +-------+--------------------+-----+----------------+--------+--------------------+-----------------+-----------------+--------+--------+-----------+-------------------+-------------+--------------+-----------------+---------------------------+-----------------+----------------------+------------------+-----------------------+------------------------------+-------------------------+------------------+
# |1030830|MafiaIIDefinitive...|    0|        77191065| english|Just fucking God ...|       1602094246|       1602094246|   false|       0|          0|                0.0|            0|          true|            false|                      false|76561198329320604|                    55|                 5|                     83|                            83|                       83|        1602093984|
# |1030830|MafiaIIDefinitive...|    1|        77189401| english|Another masterpie...|       1602092025|       1602092025|    true|       0|          0|                0.0|            0|          true|            false|                      false|76561198271082576|                   113|                24|                    686|                           686|                      686|        1602091951|
# |1030830|MafiaIIDefinitive...|    2|        77187242| english|Best in series up...|       1602089175|       1602089175|    true|       0|          0|                0.0|            0|          true|            false|                      false|76561198049220968|                    47|                 2|                    540|                           540|                      537|        1602089374|
# |1030830|MafiaIIDefinitive...|    3|        77168878| english|               good |       1602061837|       1602061837|    true|       0|          0|                0.0|            0|          true|            false|                      false|76561198842120161|                   113|                 2|                    622|                           566|                      561|        1602065604|
# |1030830|MafiaIIDefinitive...|    4|        77167717| english|Can't Load proper...|       1602059915|       1602059915|   false|       0|          0|                0.0|            0|          true|            false|                      false|76561198034355239|                   598|                 6|                     70|                            70|                       70|        1602059550|
# |1030830|MafiaIIDefinitive...|    5|        77155497| english|I think I ended u...|       1602035897|       1602035897|   false|       1|          0| 0.4316239058971405|            0|          true|            false|                      false|76561198004620648|                   189|                31|                    693|                           693|                      693|        1602035747|
# |1030830|MafiaIIDefinitive...|    6|        77152720| english|            Its good|       1602030444|       1602030444|    true|       0|          0| 0.4969879686832428|            0|          true|            false|                      false|76561198431670615|                    50|                 7|                    751|                           751|                      751|        1602030409|
# |1030830|MafiaIIDefinitive...|    7|        77152308| english|if all the hype i...|       1602029658|       1602029693|    true|       0|          0| 0.4969879686832428|            0|          true|            false|                      false|76561198126084856|                    46|                 9|                   1342|                           892|                     1342|        1602027621|
# |1030830|MafiaIIDefinitive...|    8|        77150178| english|Shame that you ca...|       1602025565|       1602025565|    true|       1|          0| 0.5208034515380859|            0|          true|             true|                      false|76561198062504928|                   113|                 8|                      8|                             0|                        8|        1590726631|
# |1030830|MafiaIIDefinitive...|    9|        77148883| english|Sadece texture'la...|       1602023109|       1602023109|   false|       2|          0| 0.5244956612586975|            0|          true|            false|                      false|76561198174518810|                   144|                 6|                    889|                           889|                      889|        1602023043|
# |1030830|MafiaIIDefinitive...|   10|        77142467| english|9.5/10 Such a gre...|       1602012952|       1602012952|    true|       0|          0| 0.4969879686832428|            0|          true|            false|                      false|76561198104791786|                    73|                28|                    914|                           173|                      914|        1601760362|
# |1030830|MafiaIIDefinitive...|   11|        77118716| english|Worst driving out...|       1601976956|       1601976956|   false|       0|          0| 0.3816037178039551|            0|          true|            false|                      false|76561198048172832|                    94|                 1|                    150|                           150|                      150|        1601976847|
# |1030830|MafiaIIDefinitive...|   12|        77098336| english|Mr. Salieri sends...|       1601934315|       1601934315|    true|       1|          0|  0.525547444820404|            0|          true|            false|                      false|76561198166587330|                    82|                 4|                   1156|                           661|                     1131|        1601936042|
# |1030830|MafiaIIDefinitive...|   13|        77094851| english|"This game is one...|       1601928530|       1601928530|   false|       4|          0| 0.5803990364074707|            0|          true|             true|                      false|76561197960350664|                   716|                22|                    877|                           877|                      877|        1601927427|
# |1030830|MafiaIIDefinitive...|   14|        77092782| english|Don't but it if y...|       1601925569|       1601925569|    true|       0|          0|                0.0|            0|          true|            false|                      false|76561197970363691|                   247|                12|                    591|                           591|                      591|        1601925481|
# |1030830|MafiaIIDefinitive...|   15|        77078004| english|This is Pizdectfy...|       1601905154|       1601905154|    true|       1|          0|  0.523809552192688|            0|          true|            false|                      false|76561198825686417|                    10|                 4|                    325|                           325|                      244|        1601923640|
# |1030830|MafiaIIDefinitive...|   16|        77068397| english|            Ehy Vito|       1601888564|       1601888564|    true|       0|          0|                0.0|            0|          true|            false|                      false|76561198065128919|                    98|                10|                    992|                           992|                      992|        1601871397|
# |1030830|MafiaIIDefinitive...|   17|        77053259| english|"Bought the defin...|       1601857495|       1601857495|    true|       0|          0|                0.0|            0|          true|            false|                      false|76561197966786200|                   196|                64|                   1955|                          1955|                     1955|        1601798164|
# |1030830|MafiaIIDefinitive...|   18|        76886592| english|I AM FUCKING PISS...|       1601598166|       1601851795|   false|       0|          2|                0.0|            2|          true|            false|                      false|76561198066433657|                   335|                 2|                    901|                           901|                      901|        1601597689|
# |1030830|MafiaIIDefinitive...|   19|        77049870| english|DO NOT BUY THIS C...|       1601851098|       1601851289|   false|       3|          0|   0.54356849193573|            0|          true|            false|                      false|76561198040205907|                   237|                58|                     11|                            11|                       11|        1601841902|
# +-------+--------------------+-----+----------------+--------+--------------------+-----------------+-----------------+--------+--------+-----------+-------------------+-------------+--------------+-----------------+---------------------------+-----------------+----------------------+------------------+-----------------------+------------------------------+-------------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# # Process Further and optimize
#
# Now that the data is stored as a deltatable we further process it by removing unncesessary columns, fixing game names, ...

# %%
reviews.count()
# Out:
# 4592067

# %%
rdd = reviews.rdd

# %% [markdown]
# # Fix the game names
#
# Get the distinct game names, then ask chatGPT to fix the names and use the appid as the key to update the names.

# %%
distinct_game_names = (
    rdd.map(lambda row: ((row["appid"], row["game"]), 1))
    .reduceByKey(lambda acc, _: acc)
    .map(lambda game: game[0])
    .collect()
)
distinct_game_names
# Out:
# [('1085660', 'Destiny2'),
#  ('284160', 'BeamNGdrive'),
#  ('325610', 'TotalWarATTILA'),
#  ('440900', 'ConanExiles'),
#  ('493340', 'PlanetCoaster'),
#  ('644930', 'TheyAreBillions'),
#  ('666140', 'MyTimeAtPortia'),
#  ('962130', 'Grounded'),
#  ('221100', 'DayZ'),
#  ('236850', 'EuropaUniversalisIV'),
#  ('377160', 'Fallout4'),
#  ('383980', 'RivalsofAether'),
#  ('393380', 'Squad'),
#  ('200210', 'RealmoftheMadGodExalt'),
#  ('218620', 'PAYDAY2'),
#  ('233860', 'Kenshi'),
#  ('311690', 'EntertheGungeon'),
#  ('322170', 'GeometryDash'),
#  ('335300', 'DARKSOULSIIScholaroftheFirstSin'),
#  ('418530', 'Spelunky2'),
#  ('212680', 'FTLFasterThanLight'),
#  ('234140', 'MadMax'),
#  ('244210', 'AssettoCorsa'),
#  ('361420', 'ASTRONEER'),
#  ('477160', 'HumanFallFlat'),
#  ('489830', 'TheElderScrollsVSkyrimSpecialEdition'),
#  ('812140', 'AssassinsCreedOdyssey'),
#  ('863550', 'HITMAN2'),
#  ('945360', 'AmongUs'),
#  ('997070', 'MarvelsAvengers'),
#  ('105600', 'Terraria'),
#  ('1097150', 'FallGuys'),
#  ('1151340', 'Fallout76'),
#  ('1238860', 'Battlefield4'),
#  ('380600', 'FishingPlanet'),
#  ('648800', 'Raft'),
#  ('787860', 'FarmingSimulator19'),
#  ('815370', 'GreenHell'),
#  ('1190460', 'DEATHSTRANDING'),
#  ('1250410', 'MicrosoftFlightSimulator'),
#  ('252490', 'Rust'),
#  ('1080110', 'F12020'),
#  ('1030840', 'MafiaDefinitiveEdition'),
#  ('1174180', 'RedDeadRedemption2'),
#  ('251570', '7DaystoDie'),
#  ('508440', 'TotallyAccurateBattleSimulator'),
#  ('900883', 'TheElderScrollsIVOblivion'),
#  ('214950', 'TotalWarROMEIIEmperorEdition'),
#  ('240', 'CounterStrikeSource'),
#  ('268500', 'XCOM2'),
#  ('34030', 'TotalWarNAPOLEONDefinitiveEdition'),
#  ('379430', 'KingdomComeDeliverance'),
#  ('582010', 'MonsterHunterWorld'),
#  ('582660', 'BlackDesertOnline'),
#  ('613100', 'HouseFlipper'),
#  ('413150', 'StardewValley'),
#  ('211820', 'Starbound'),
#  ('244450', 'MenofWarAssaultSquad2'),
#  ('250900', 'TheBindingofIsaacRebirth'),
#  ('262060', 'DarkestDungeon'),
#  ('359320', 'EliteDangerous'),
#  ('632360', 'RiskofRain2'),
#  ('1066780', 'TransportFever2'),
#  ('1217060', 'GunfireReborn'),
#  ('550', 'Left4Dead2'),
#  ('703080', 'PlanetZoo'),
#  ('719040', 'Wasteland3'),
#  ('72850', 'TheElderScrollsVSkyrim'),
#  ('739630', 'Phasmophobia'),
#  ('872790', 'FootballManager2019'),
#  ('996470', 'eFootballPES2020'),
#  ('232090', 'KillingFloor2'),
#  ('244850', 'SpaceEngineers'),
#  ('367500', 'DragonsDogmaDarkArisen'),
#  ('47890', 'TheSims3'),
#  ('49520', 'Borderlands2'),
#  ('678950', 'DRAGONBALLFighterZ'),
#  ('813780', 'AgeofEmpiresIIDefinitiveEdition'),
#  ('824270', 'KovaaK20'),
#  ('275850', 'NoMansSky'),
#  ('289070', 'SidMeiersCivilizationVI'),
#  ('311210', 'CallofDutyBlackOpsIII'),
#  ('34460', 'SidMeiersCivilizationIVBeyondtheSword'),
#  ('367520', 'HollowKnight'),
#  ('389730', 'TEKKEN7'),
#  ('418460', 'RisingStorm2Vietnam'),
#  ('219990', 'GrimDawn'),
#  ('281990', 'Stellaris'),
#  ('294100', 'RimWorld'),
#  ('4000', 'GarrysMod'),
#  ('1087280', 'OutoftheParkBaseball21'),
#  ('1113000', 'Persona4Golden'),
#  ('387990', 'ScrapMechanic'),
#  ('552500', 'WarhammerVermintide2'),
#  ('646570', 'SlaytheSpire'),
#  ('686810', 'HellLetLoose'),
#  ('10500', 'TotalWarEMPIREDefinitiveEdition'),
#  ('1089350', 'NBA2K20'),
#  ('257420', 'SeriousSam4'),
#  ('346110', 'ARKSurvivalEvolved'),
#  ('365360', 'BattleBrothers'),
#  ('412020', 'MetroExodus'),
#  ('573090', 'StormworksBuildandRescue'),
#  ('814380', 'SekiroShadowsDieTwice'),
#  ('1172620', 'SeaofThieves'),
#  ('1259970', 'eFootballPES2021SEASONUPDATE'),
#  ('242760', 'TheForest'),
#  ('266840', 'AgeofMythologyExtendedEdition'),
#  ('304390', 'ForHonor'),
#  ('359550', 'TomClancysRainbowSixSiege'),
#  ('581320', 'InsurgencySandstorm'),
#  ('620980', 'BeatSaber'),
#  ('382310', 'Eco'),
#  ('39210', 'FINALFANTASYXIVOnline'),
#  ('227300', 'EuroTruckSimulator2'),
#  ('314160', 'MicrosoftFlightSimulatorXSteamEdition'),
#  ('334230', 'TownofSalem'),
#  ('374320', 'DARKSOULSIII'),
#  ('1100600', 'FootballManager2020'),
#  ('221380', 'AgeofEmpiresII2013'),
#  ('32470', 'STARWARSEmpireatWarGoldPack'),
#  ('4760', 'RomeTotalWar'),
#  ('637090', 'BATTLETECH'),
#  ('1030830', 'MafiaIIDefinitiveEdition'),
#  ('1129580', 'MedievalDynasty'),
#  ('1094520', 'SandsofSalzaar'),
#  ('1102190', 'MonsterTrain'),
#  ('1225330', 'NBA2K21'),
#  ('239140', 'DyingLight'),
#  ('287700', 'METALGEARSOLIDVTHEPHANTOMPAIN'),
#  ('427520', 'Factorio'),
#  ('431960', 'WallpaperEngine'),
#  ('457140', 'OxygenNotIncluded'),
#  ('513710', 'SCUM'),
#  ('552520', 'FarCry5'),
#  ('834910', 'ATLAS'),
#  ('1283970', 'YoloMouse'),
#  ('201270', 'TotalWarSHOGUN2'),
#  ('220200', 'KerbalSpaceProgram'),
#  ('356190', 'MiddleearthShadowofWar'),
#  ('594570', 'TotalWarWARHAMMERII'),
#  ('594650', 'HuntShowdown'),
#  ('394360', 'HeartsofIronIV'),
#  ('397540', 'Borderlands3'),
#  ('264710', 'Subnautica'),
#  ('270880', 'AmericanTruckSimulator'),
#  ('629760', 'MORDHAU'),
#  ('107410', 'Arma3'),
#  ('1222670', 'TheSims4'),
#  ('310950', 'StreetFighterV'),
#  ('431730', 'Aseprite'),
#  ('524220', 'NieRAutomata'),
#  ('805550', 'AssettoCorsaCompetizione'),
#  ('976310', 'MortalKombat11'),
#  ('4700', 'TotalWarMEDIEVALIIDefinitiveEdition'),
#  ('570940', 'DARKSOULSREMASTERED'),
#  ('640820', 'PathfinderKingmaker'),
#  ('645630', 'CarMechanicSimulator2018'),
#  ('960090', 'BloonsTD6'),
#  ('208650', 'BatmanArkhamKnight'),
#  ('261550', 'MountBladeIIBannerlord'),
#  ('286160', 'TabletopSimulator'),
#  ('620', 'Portal2'),
#  ('274920', 'FaceRig'),
#  ('322330', 'DontStarveTogether'),
#  ('578080', 'PLAYERUNKNOWNSBATTLEGROUNDS'),
#  ('1213210', 'CommandConquerRemasteredCollection'),
#  ('381210', 'DeadbyDaylight'),
#  ('782330', 'DOOMEternal'),
#  ('976730', 'HaloTheMasterChiefCollection'),
#  ('105450', 'AgeofEmpiresIII2007'),
#  ('10', 'CounterStrike'),
#  ('1118200', 'PeoplePlayground'),
#  ('1151640', 'HorizonZeroDawn'),
#  ('1100620', 'FootballManager2020Touch'),
#  ('383120', 'EmpyrionGalacticSurvival'),
#  ('466560', 'Northgard'),
#  ('48700', 'MountBladeWarband'),
#  ('526870', 'Satisfactory'),
#  ('548430', 'DeepRockGalactic'),
#  ('719890', 'BeastsofBermuda'),
#  ('779340', 'TotalWarTHREEKINGDOMS'),
#  ('1307550', 'Craftopia'),
#  ('306130', 'TheElderScrollsOnline'),
#  ('376210', 'TheIsle')]

# %%
# Asked chatGPT to "fix" the game names by adding spaces, special characters and titleling correctly and so on
# fmt: off
game_names = {"377160": "Fallout 4", "211820": "Starbound", "221100": "DayZ", "294100": "RimWorld", "244450": "Men of War: Assault Squad 2", "250900": "The Binding of Isaac: Rebirth", "107410": "Arma 3", "1087280": "Out of the Park Baseball 21", "1097150": "Fall Guys", "264710": "Subnautica", "270880": "American Truck Simulator", "1066780": "Transport Fever 2", "644930": "They Are Billions", "739630": "Phasmophobia", "782330": "DOOM Eternal", "32470": "STAR WARS Empire at War: Gold Pack", "431730": "Aseprite", "493340": "Planet Coaster", "550": "Left 4 Dead 2", "552500": "Warhammer: Vermintide 2", "393380": "Squad", "4000": "Garry's Mod", "1030840": "Mafia: Definitive Edition", "1100620": "Football Manager 2020 Touch", "640820": "Pathfinder: Kingmaker", "812140": "Assassin's Creed Odyssey", "361420": "ASTRONEER", "49520": "Borderlands 2", "548430": "Deep Rock Galactic", "570940": "DARK SOULS: REMASTERED", "379430": "Kingdom Come: Deliverance", "34460": "Sid Meier's Civilization IV: Beyond the Sword", "367520": "Hollow Knight", "1307550": "Craftopia", "218620": "PAYDAY 2", "289070": "Sid Meier's Civilization VI", "311690": "Enter the Gungeon", "594570": "Total War: WARHAMMER II", "613100": "House Flipper", "105450": "Age of Empires III (2007)", "1118200": "People Playground", "997070": "Marvel's Avengers", "374320": "DARK SOULS III", "1190460": "DEATH STRANDING", "1250410": "Microsoft Flight Simulator", "314160": "Microsoft Flight Simulator X: Steam Edition", "1151340": "Fallout 76", "976310": "Mortal Kombat 11", "262060": "Darkest Dungeon", "1217060": "Gunfire Reborn", "637090": "BATTLETECH", "646570": "Slay the Spire", "666140": "My Time At Portia", "703080": "Planet Zoo", "719040": "Wasteland 3", "1225330": "NBA 2K21", "212680": "FTL: Faster Than Light", "239140": "Dying Light", "244850": "Space Engineers", "346110": "ARK: Survival Evolved", "457140": "Oxygen Not Included", "47890": "The Sims 3", "526870": "Satisfactory", "418530": "Spelunky 2", "1172620": "Sea of Thieves", "200210": "Realm of the Mad God Exalt", "286160": "Tabletop Simulator", "304390": "For Honor", "242760": "The Forest", "582010": "Monster Hunter: World", "594650": "Hunt: Showdown", "1089350": "NBA 2K20", "813780": "Age of Empires II: Definitive Edition", "227300": "Euro Truck Simulator 2", "648800": "Raft", "686810": "Hell Let Loose", "310950": "Street Fighter V", "325610": "Total War: ATTILA", "381210": "Dead by Daylight", "4760": "Rome: Total War", "268500": "XCOM 2", "1094520": "Sands of Salzaar", "244210": "Assetto Corsa", "251570": "7 Days to Die", "678950": "DRAGON BALL FighterZ", "365360": "Battle Brothers", "383120": "Empyrion: Galactic Survival", "427520": "Factorio", "466560": "Northgard", "489830": "The Elder Scrolls V: Skyrim Special Edition", "508440": "Totally Accurate Battle Simulator", "552520": "Far Cry 5", "418460": "Rising Storm 2: Vietnam", "1259970": "eFootball PES 2021 SEASON UPDATE", "1283970": "YoloMouse", "220200": "Kerbal Space Program", "311210": "Call of Duty: Black Ops III", "322170": "Geometry Dash", "1030830": "Mafia II: Definitive Edition", "10500": "Total War: EMPIRE Definitive Edition", "10": "Counter-Strike", "824270": "KovaaK's 2.0", "834910": "ATLAS", "334230": "Town of Salem", "359320": "Elite Dangerous", "219990": "Grim Dawn", "281990": "Stellaris", "322330": "Don't Starve Together", "578080": "PLAYERUNKNOWN'S BATTLEGROUNDS", "105600": "Terraria", "1113000": "Persona 4 Golden", "815370": "Green Hell", "872790": "Football Manager 2019", "976730": "Halo: The Master Chief Collection", "1238860": "Battlefield 4", "787860": "Farming Simulator 19", "387990": "Scrap Mechanic", "440900": "Conan Exiles", "524220": "NieR: Automata", "383980": "Rivals of Aether", "261550": "Mount & Blade II: Bannerlord", "232090": "Killing Floor 2", "234140": "Mad Max", "779340": "Total War: THREE KINGDOMS", "287700": "METAL GEAR SOLID V: THE PHANTOM PAIN", "573090": "Stormworks: Build and Rescue", "389730": "TEKKEN 7", "394360": "Hearts of Iron IV", "397540": "Borderlands 3", "376210": "The Isle", "306130": "The Elder Scrolls Online", "620980": "Beat Saber", "620": "Portal 2", "1080110": "F1 2020", "814380": "Sekiro: Shadows Die Twice", "900883": "The Elder Scrolls IV: Oblivion", "945360": "Among Us", "960090": "Bloons TD 6", "236850": "Europa Universalis IV", "252490": "Rust", "629760": "MORDHAU", "632360": "Risk of Rain 2", "1085660": "Destiny 2", "1100600": "Football Manager 2020", "962130": "Grounded", "996470": "eFootball PES 2020", "274920": "FaceRig", "1213210": "Command & Conquer Remastered Collection", "1222670": "The Sims 4", "221380": "Age of Empires II (2013)", "72850": "The Elder Scrolls V: Skyrim", "805550": "Assetto Corsa Competizione", "284160": "BeamNG.drive", "380600": "Fishing Planet", "266840": "Age of Mythology: Extended Edition", "275850": "No Man's Sky", "1102190": "Monster Train", "1174180": "Red Dead Redemption 2", "645630": "Car Mechanic Simulator 2018", "719890": "Beasts of Bermuda", "257420": "Serious Sam 4", "367500": "Dragon's Dogma: Dark Arisen", "412020": "Metro Exodus", "431960": "Wallpaper Engine", "4700": "Total War: MEDIEVAL II Definitive Edition", "477160": "Human: Fall Flat", "48700": "Mount & Blade: Warband", "513710": "SCUM", "382310": "Eco", "39210": "FINAL FANTASY XIV Online", "413150": "Stardew Valley", "335300": "DARK SOULS II: Scholar of the First Sin", "34030": "Total War: NAPOLEON Definitive Edition", "356190": "Middle-earth: Shadow of War", "359550": "Tom Clancy's Rainbow Six Siege", "1151640": "Horizon Zero Dawn", "201270": "Total War: SHOGUN 2", "208650": "Batman: Arkham Knight", "214950": "Total War: ROME II Emperor Edition", "233860": "Kenshi", "240": "Counter-Strike: Source", "581320": "Insurgency: Sandstorm", "582660": "Black Desert Online", "1129580": "Medieval Dynasty", "863550": "HITMAN 2"}
# fmt: on

# %% [markdown]
# # Table

# %%
def rename_game_column(data: tuple[RDD, str]):
    row, appid = data
    new_row = {}
    for col, val in row.asDict().items():
        if col == "game":
            val = game_names[appid]
        new_row[col] = val
    return Row(**new_row)

# %%
drop = [
    "index",
    "timestamp_created",
    "timestamp_updated",
    "votes_up",
    "votes_funny",
    "steam_purchase",
    "received_for_free",
    "author_num_games_owned",
    "author_last_played",
    "weighted_vote_score",
    "written_during_early_access",
    "comment_count",
    "author_playtime_last_two_weeks",
    "author_playtime_at_review",
]

# %%
def remove_columns(row: RDD):
    return Row(**{k: v for k, v in row.asDict().items() if k not in drop})

# %% [markdown]
# # Preprocess

# %%
rdd.take(10)
# Out:
# [Row(appid='1030830', game='MafiaIIDefinitiveEdition', index='0', recommendationid='77191065', language='english', review='Just fucking God knows -  why this game weight 44 GB while original game only 8.  I dont see that improvements for extra 36GD -  only a stupid car from 3rd Mafia -  which you cannot even upgrade properly.', timestamp_created=1602094246, timestamp_updated=1602094246, voted_up=False, votes_up=0, votes_funny=0, weighted_vote_score=0.0, comment_count=0, steam_purchase=True, received_for_free=False, written_during_early_access=False, author_steamid='76561198329320604', author_num_games_owned=55, author_num_reviews=5, author_playtime_forever=83, author_playtime_last_two_weeks=83, author_playtime_at_review=83, author_last_played=1602093984),
#  Row(appid='1030830', game='MafiaIIDefinitiveEdition', index='1', recommendationid='77189401', language='english', review="Another masterpiece doesn't let down the series", timestamp_created=1602092025, timestamp_updated=1602092025, voted_up=True, votes_up=0, votes_funny=0, weighted_vote_score=0.0, comment_count=0, steam_purchase=True, received_for_free=False, written_during_early_access=False, author_steamid='76561198271082576', author_num_games_owned=113, author_num_reviews=24, author_playtime_forever=686, author_playtime_last_two_weeks=686, author_playtime_at_review=686, author_last_played=1602091951),
#  Row(appid='1030830', game='MafiaIIDefinitiveEdition', index='2', recommendationid='77187242', language='english', review="Best in series up until the remaster of the first Mafia game. If you like linear open worlds like GTA you'll enjoy the refreshing map of empire city and have fun either shooting rival mobs or customizing your car for some hot rodding. definite 8/10.", timestamp_created=1602089175, timestamp_updated=1602089175, voted_up=True, votes_up=0, votes_funny=0, weighted_vote_score=0.0, comment_count=0, steam_purchase=True, received_for_free=False, written_during_early_access=False, author_steamid='76561198049220968', author_num_games_owned=47, author_num_reviews=2, author_playtime_forever=540, author_playtime_last_two_weeks=540, author_playtime_at_review=537, author_last_played=1602089374),
#  Row(appid='1030830', game='MafiaIIDefinitiveEdition', index='3', recommendationid='77168878', language='english', review='good ', timestamp_created=1602061837, timestamp_updated=1602061837, voted_up=True, votes_up=0, votes_funny=0, weighted_vote_score=0.0, comment_count=0, steam_purchase=True, received_for_free=False, written_during_early_access=False, author_steamid='76561198842120161', author_num_games_owned=113, author_num_reviews=2, author_playtime_forever=622, author_playtime_last_two_weeks=566, author_playtime_at_review=561, author_last_played=1602065604),
#  Row(appid='1030830', game='MafiaIIDefinitiveEdition', index='4', recommendationid='77167717', language='english', review="Can't Load properly and the graphic is bad.  Go play mafia 1 definitive edition. It is way better.", timestamp_created=1602059915, timestamp_updated=1602059915, voted_up=False, votes_up=0, votes_funny=0, weighted_vote_score=0.0, comment_count=0, steam_purchase=True, received_for_free=False, written_during_early_access=False, author_steamid='76561198034355239', author_num_games_owned=598, author_num_reviews=6, author_playtime_forever=70, author_playtime_last_two_weeks=70, author_playtime_at_review=70, author_last_played=1602059550),
#  Row(appid='1030830', game='MafiaIIDefinitiveEdition', index='5', recommendationid='77155497', language='english', review="I think I ended up hating this game even more than the first game. Somehow they managed to make the remake even worse. The audio is worse than the game released ten years ago and the missions are still as hit and miss. One mission will be either like climbing up a mountain or shooting a man in a wheelchair who has no hands. This is a ten dollar game pretending to be 40 bucks. Visual bugs out the wazoo for a supposedly remastered game. And typos in the subtitles? Really? You can't even proofread?", timestamp_created=1602035897, timestamp_updated=1602035897, voted_up=False, votes_up=1, votes_funny=0, weighted_vote_score=0.4316239058971405, comment_count=0, steam_purchase=True, received_for_free=False, written_during_early_access=False, author_steamid='76561198004620648', author_num_games_owned=189, author_num_reviews=31, author_playtime_forever=693, author_playtime_last_two_weeks=693, author_playtime_at_review=693, author_last_played=1602035747),
#  Row(appid='1030830', game='MafiaIIDefinitiveEdition', index='6', recommendationid='77152720', language='english', review='Its good', timestamp_created=1602030444, timestamp_updated=1602030444, voted_up=True, votes_up=0, votes_funny=0, weighted_vote_score=0.4969879686832428, comment_count=0, steam_purchase=True, received_for_free=False, written_during_early_access=False, author_steamid='76561198431670615', author_num_games_owned=50, author_num_reviews=7, author_playtime_forever=751, author_playtime_last_two_weeks=751, author_playtime_at_review=751, author_last_played=1602030409),
#  Row(appid='1030830', game='MafiaIIDefinitiveEdition', index='7', recommendationid='77152308', language='english', review="if all the hype i heard about mafia series mafia 2 is my first game i play in the series now im waiting for mafia 1 remake go low price so i can play it i love the story is great game-play is smooth. but it had minor glitches with is remastered  the only thing i do not like about this game is the shooting it does not hit the enemy's right hard to shoot. also the ai is way too op they had alot of health good luck try to one shot em  but after all this i enjoy it i give this 8/10", timestamp_created=1602029658, timestamp_updated=1602029693, voted_up=True, votes_up=0, votes_funny=0, weighted_vote_score=0.4969879686832428, comment_count=0, steam_purchase=True, received_for_free=False, written_during_early_access=False, author_steamid='76561198126084856', author_num_games_owned=46, author_num_reviews=9, author_playtime_forever=1342, author_playtime_last_two_weeks=892, author_playtime_at_review=1342, author_last_played=1602027621),
#  Row(appid='1030830', game='MafiaIIDefinitiveEdition', index='8', recommendationid='77150178', language='english', review='Shame that you can no longer just purchase the original. This release only exists so that 2k could re-sell a classic at a higher price. The graphical changes are cool I guess but not worth it imo.  If you do purchase this version you can still play the original version -  simply install mafia II classic. Buy on sale.', timestamp_created=1602025565, timestamp_updated=1602025565, voted_up=True, votes_up=1, votes_funny=0, weighted_vote_score=0.5208034515380859, comment_count=0, steam_purchase=True, received_for_free=True, written_during_early_access=False, author_steamid='76561198062504928', author_num_games_owned=113, author_num_reviews=8, author_playtime_forever=8, author_playtime_last_two_weeks=0, author_playtime_at_review=8, author_last_played=1590726631),
#  Row(appid='1030830', game='MafiaIIDefinitiveEdition', index='9', recommendationid='77148883', language='english', review="Sadece texture'lar ve shader'lari arttirmislar ama bunun yaninda bir suru bug ile geliyor. Classic versiyonu oynayin 50 gb indirmenin manasi yok.", timestamp_created=1602023109, timestamp_updated=1602023109, voted_up=False, votes_up=2, votes_funny=0, weighted_vote_score=0.5244956612586975, comment_count=0, steam_purchase=True, received_for_free=False, written_during_early_access=False, author_steamid='76561198174518810', author_num_games_owned=144, author_num_reviews=6, author_playtime_forever=889, author_playtime_last_two_weeks=889, author_playtime_at_review=889, author_last_played=1602023043)]

# %% [markdown]
# num rows with missing values before dropping columns

# %%
num_rows_with_missing_values = (
    rdd.filter(lambda row: None in row.asDict().values())
    .map(lambda row: 1)
    .reduce(lambda x, y: x + y)
)
num_rows_with_missing_values
# Out:
# 190869

# %%
# Removie columns that we decided we won't use.
rdd = rdd.map(remove_columns)

# %% [markdown]
# num rows missing values after removing columns

# %%
num_rows_with_missing_values = (
    rdd.filter(lambda row: None in row.asDict().values())
    .map(lambda row: 1)
    .reduce(lambda x, y: x + y)
)
num_rows_with_missing_values
# Out:
# 10063

# %%
# Remove rows with missing valuse
rdd = rdd.filter(lambda row: None not in row.asDict().values())

# %%
# Fix the names in the game column.
rdd = rdd.map(lambda row: (row, row["appid"])).map(rename_game_column)

# %%
df = rdd.toDF()
df.show()
# Out:
# +-------+--------------------+----------------+--------+--------------------+--------+-----------------+------------------+-----------------------+
# |  appid|                game|recommendationid|language|              review|voted_up|   author_steamid|author_num_reviews|author_playtime_forever|
# +-------+--------------------+----------------+--------+--------------------+--------+-----------------+------------------+-----------------------+
# |1030830|Mafia II: Definit...|        77191065| english|Just fucking God ...|   false|76561198329320604|                 5|                     83|
# |1030830|Mafia II: Definit...|        77189401| english|Another masterpie...|    true|76561198271082576|                24|                    686|
# |1030830|Mafia II: Definit...|        77187242| english|Best in series up...|    true|76561198049220968|                 2|                    540|
# |1030830|Mafia II: Definit...|        77168878| english|               good |    true|76561198842120161|                 2|                    622|
# |1030830|Mafia II: Definit...|        77167717| english|Can't Load proper...|   false|76561198034355239|                 6|                     70|
# |1030830|Mafia II: Definit...|        77155497| english|I think I ended u...|   false|76561198004620648|                31|                    693|
# |1030830|Mafia II: Definit...|        77152720| english|            Its good|    true|76561198431670615|                 7|                    751|
# |1030830|Mafia II: Definit...|        77152308| english|if all the hype i...|    true|76561198126084856|                 9|                   1342|
# |1030830|Mafia II: Definit...|        77150178| english|Shame that you ca...|    true|76561198062504928|                 8|                      8|
# |1030830|Mafia II: Definit...|        77148883| english|Sadece texture'la...|   false|76561198174518810|                 6|                    889|
# |1030830|Mafia II: Definit...|        77142467| english|9.5/10 Such a gre...|    true|76561198104791786|                28|                    914|
# |1030830|Mafia II: Definit...|        77118716| english|Worst driving out...|   false|76561198048172832|                 1|                    150|
# |1030830|Mafia II: Definit...|        77098336| english|Mr. Salieri sends...|    true|76561198166587330|                 4|                   1156|
# |1030830|Mafia II: Definit...|        77094851| english|"This game is one...|   false|76561197960350664|                22|                    877|
# |1030830|Mafia II: Definit...|        77092782| english|Don't but it if y...|    true|76561197970363691|                12|                    591|
# |1030830|Mafia II: Definit...|        77078004| english|This is Pizdectfy...|    true|76561198825686417|                 4|                    325|
# |1030830|Mafia II: Definit...|        77068397| english|            Ehy Vito|    true|76561198065128919|                10|                    992|
# |1030830|Mafia II: Definit...|        77053259| english|"Bought the defin...|    true|76561197966786200|                64|                   1955|
# |1030830|Mafia II: Definit...|        76886592| english|I AM FUCKING PISS...|   false|76561198066433657|                 2|                    901|
# |1030830|Mafia II: Definit...|        77049870| english|DO NOT BUY THIS C...|   false|76561198040205907|                58|                     11|
# +-------+--------------------+----------------+--------+--------------------+--------+-----------------+------------------+-----------------------+
# only showing top 20 rows

# %%
df.count()
# Out:
# 4582004

# %%
rdd = df.rdd

# %%
total_num_authors = (
    rdd.map(lambda row: (row["author_steamid"], 1))
    .reduceByKey(lambda acc, id: acc)
    .map(lambda x: 1)
    .reduce(lambda x, y: x + y)
)
total_num_authors
# Out:
# 3091493

# %%
distinct_authorids = (
    rdd.map(lambda row: (row["author_steamid"], 1))
    .reduceByKey(lambda acc, id: acc)
    .map(lambda row: row[0])
    .collect()
)
distinct_authorids
# Out:
# ['76561198065128919',
#  '76561198865948243',
#  '76561198857009362',
#  '76561198846517279',
#  '76561198306705878',
#  '76561198236015050',
#  '76561198093500364',
#  '76561198090765334',
#  '76561198056608663',
#  '76561198129285788',
#  '76561197968519809',
#  '76561198079070333',
#  '76561197995424812',
#  '76561199019236878',
#  '76561198410918961',
#  '76561197963369971',
#  '76561198193252390',
#  '76561198263712087',
#  '76561198296875526',
#  '76561198140898545',
#  '76561198155919173',
#  '76561198061168308',
#  '76561198116645838',
#  '76561198247972198',
#  '76561197972187848',
#  '76561198012228997',
#  '76561198350554329',
#  '76561198165085750',
#  '76561198112669314',
#  '76561198036077253',
#  '76561198012601406',
#  '76561198102869445',
#  '76561198082489808',
#  '76561198159706647',
#  '76561198119100474',
#  '76561198190494466',
#  '76561198099444008',
#  '76561198125019081',
#  '76561198142259772',
#  '76561198360881920',
#  ...]

# %%
# Due to issues with converting the author_steamids to integers for the large numbers, we remap to smaller ids
ids = [i for i in range(1000000, 9999999)]

author_map = {}
for i, author in enumerate(distinct_authorids):
    author_map[author] = ids[i]

# %%
def recreate_userid(data: RDD):
    return Row(
        **{
            k: author_map[v] if k == "author_steamid" else v
            for k, v in data.asDict().items()
        }
    )

# %%
rdd = rdd.map(recreate_userid)

# %%
df = rdd.toDF()
df.write.format("delta").mode("overwrite").save(DELTA_TABLE)

# %%
df = spark.read.format("delta").load(DELTA_TABLE)
df.show()
# Out:
# +------+-------------+----------------+--------+--------------------+--------+--------------+------------------+-----------------------+
# | appid|         game|recommendationid|language|              review|voted_up|author_steamid|author_num_reviews|author_playtime_forever|
# +------+-------------+----------------+--------+--------------------+--------+--------------+------------------+-----------------------+
# |334230|Town of Salem|        33616217| english|Good for people w...|    true|       3398771|                 5|                   4201|
# |334230|Town of Salem|        33615630| english|              Fun af|    true|       3398772|                 2|                    917|
# |334230|Town of Salem|        33615126| english|People throw game...|   false|       2580799|                 8|                    155|
# |334230|Town of Salem|        33611378| english|this game is addi...|    true|       2632514|                 1|                   5871|
# |334230|Town of Salem|        33594117| english|This games is enj...|    true|       2190394|                 4|                  18828|
# |334230|Town of Salem|        33587915| english|-Get mafia -Prete...|    true|       2957247|                 3|                   6860|
# |334230|Town of Salem|        33587889| english|No one ever beliv...|    true|       1065313|                15|                   3825|
# |334230|Town of Salem|        33575042| english|   fun game worth 5$|    true|       2367984|                38|                   3792|
# |334230|Town of Salem|        33574409| english|Play it on a web ...|   false|       3073377|                11|                   1319|
# |334230|Town of Salem|        33574252| english|Fun and played fo...|    true|       2515923|                 1|                   4666|
# |334230|Town of Salem|        33573254| english|Amazing game had ...|    true|       2074114|                 3|                   2599|
# |334230|Town of Salem|        33570132| english|Rage So much i go...|    true|       3954449|                 9|                   2354|
# |334230|Town of Salem|        33569360| english|This game is the ...|    true|       2957248|                 5|                   3570|
# |334230|Town of Salem|        33567482| english|This game is almo...|    true|       3073378|                 2|                   1242|
# |334230|Town of Salem|        33567473| english|             its fun|    true|       1411763|                 3|                   2061|
# |334230|Town of Salem|        33549616| english|i think this game...|    true|       2632515|                 2|                   1974|
# |334230|Town of Salem|        33549565| english|Never beliving an...|    true|       1411764|                 2|                   2831|
# |334230|Town of Salem|        33549196| english|A game full of mi...|    true|       3073379|                11|                   1946|
# |334230|Town of Salem|        33547423| english|Bring out your in...|    true|       3027071|                37|                    344|
# |334230|Town of Salem|        33540931| english|If you looking fo...|    true|       2632516|                10|                   2816|
# +------+-------------+----------------+--------+--------------------+--------+--------------+------------------+-----------------------+
# only showing top 20 rows
